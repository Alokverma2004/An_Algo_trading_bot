# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

def display_data(file_path):
    df = pd.read_csv(file_path, index_col="Date", parse_dates=True)
    df['Close'].plot(title=file_path.split('/')[-1])
    plt.show()

if __name__ == "__main__":
    data_path = "C:/Users/Alok verma/Desktop/my_trading_bot/scripts/data/AAPL.csv"
    display_data(data_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

def display_data(file_path):
    df = pd.read_csv(file_path, index_col="Date", parse_dates=True)
    df['Close'].plot(title=file_path.split('/')[-1])
    plt.show()

if __name__ == "__main__":
    data_path = "C:/Users/Alok verma/Desktop/my_trading_bot/scripts/data/AMZN.csv"
    display_data(data_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

def display_data(file_path):
    df = pd.read_csv(file_path, index_col="Date", parse_dates=True)
    df['Close'].plot(title=file_path.split('/')[-1])
    plt.show()

if __name__ == "__main__":
    data_path = "C:/Users/Alok verma/Desktop/my_trading_bot/scripts/data/GOOG.csv"
    display_data(data_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

def display_data(file_path):
    df = pd.read_csv(file_path, index_col="Date", parse_dates=True)
    df['Close'].plot(title=file_path.split('/')[-1])
    plt.show()

if __name__ == "__main__":
    data_path = "C:/Users/Alok verma/Desktop/my_trading_bot/scripts/data/MSFT.csv"
    display_data(data_path)
